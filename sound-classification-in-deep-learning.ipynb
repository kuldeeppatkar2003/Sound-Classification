# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Import Modules**

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #  Load The Dataset

# %%
paths=[]
labels=[]
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        
        
        label=filename.split('_')[-1]
        
        label=label.split('.')[0]
        labels.append(label.lower())
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
paths[:5]
# Out:
# ['/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_home_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_youth_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_near_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_search_fear.wav',
#  '/kaggle/input/toronto-emotional-speech-set-tess/TESS Toronto emotional speech set data/YAF_fear/YAF_pick_fear.wav']

# %%
labels[:5]
# Out:
# ['fear', 'fear', 'fear', 'fear', 'fear']

# %%
##Create a dataframe
df=pd.DataFrame()
df['speech']=paths
df['label']=labels
df.head()
# Out:
#                                               speech label
# 0  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 1  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 2  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 3  /kaggle/input/toronto-emotional-speech-set-tes...  fear
# 4  /kaggle/input/toronto-emotional-speech-set-tes...  fear

# %%
# in this how many labels we have having
df['label'].value_counts()
# Out:
# label
# fear       800
# angry      800
# disgust    800
# neutral    800
# sad        800
# ps         800
# happy      800
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis-
# EDA is an approach to analyzing data sets to summarize their main characteristics, often using statistical graphics and other data visualization method

# %%
pip install librosa matplotlib
# Out:
# Requirement already satisfied: librosa in /opt/conda/lib/python3.10/site-packages (0.10.2.post1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: audioread>=2.1.9 in /opt/conda/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/conda/lib/python3.10/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /opt/conda/lib/python3.10/site-packages (from librosa) (1.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.1->librosa) (3.11.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your dataframe and 'label' is a column in that dataframe
sns.countplot(x='label', data=df)

# Display the plot
plt.show()

# %%
def waveplot(data, sr,emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion,size=20)
    librosa.display.waveplot(data,sr=sr)
    plt.show()
    
def spectogram(data,sr,emotion):
    x=librosa.stft(data)
    xdb=librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(10,4))
    plt.title(emotion,size=20)
    librosa.display.specshow(xdb,sr=sr,x_axis='time',y_axis='hz')
    plt.colorbar()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# Assuming 'df' is your dataframe
emotion = 'fear'
path = df['speech'][df['label'] == emotion].values[0]
data, sampling_rate = librosa.load(path)

def waveplot(data, sr, emotion):
    plt.figure(figsize=(10, 4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def spectogram(data, sr, emotion):
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title(f'Spectrogram for {emotion}')
    plt.show()

waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label'] == emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label'] == emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label'] == emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label'] == emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label'] == emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label'] == emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr= librosa.load(filename,duration=3,offset=0.5)
    mfcc=np.mean(librosa.feature.mfcc(y=y,sr=sr,n_mfcc=40).T,axis=0)
    return mfcc

# %% [markdown]
# extract_mfcc(df['speech'][0])

# %%
# we itrate these values and function
X_mfcc=df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-285.73727, 85.78295, -2.1689117, 22.125532, ...
# 1       [-348.34332, 35.193233, -3.8413284, 14.658875,...
# 2       [-340.11435, 53.796444, -14.267782, 20.884031,...
# 3       [-306.63422, 21.259708, -4.4110823, 6.4871554,...
# 4       [-344.7548, 46.329193, -24.171413, 19.392921, ...
#                               ...
# 5595    [-374.3952, 60.864998, 0.02505877, 8.431058, -...
# 5596    [-313.96478, 39.847843, -5.6493053, -3.8675754...
# 5597    [-357.54886, 77.88605, -15.224756, 2.194633, -...
# 5598    [-353.1474, 101.68391, -14.175897, -12.037376,...
# 5599    [-389.4595, 54.042767, 1.3469982, -1.4258989, ...
# Name: speech, Length: 5600, dtype: object

# %%
X = np.expand.dims(X_mfcc,-1)
X.shape

# %%
from keras.utlis import to_categorical
y=to_categorical(df['label'])
y.shape

# %%
X=[x for x in X_mfcc]
X=np.array(X)
X.shape
# Out:
# (5600, 40)

# %%
X=np.expand_dims(X,-1)
X.shape
# Out:
# (5600, 40, 1, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc=OneHotEncoder()
y=enc.fit_transform(df[['label']])

# %%
y=y.toarray()

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(123, return_sequences=False, input_shape=(40, 1)),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 123)            │        61,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 123)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         7,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 71,747 (280.26 KB)
#  Trainable params: 71,747 (280.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X,y,validation_split=0.2,epochs=100,batch_size=512,shuffle=True)
# Out:
# Epoch 1/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - accuracy: 0.2474 - loss: 1.8771 - val_accuracy: 0.1152 - val_loss: 2.0757
# Epoch 2/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.4527 - loss: 1.5777 - val_accuracy: 0.2045 - val_loss: 1.8136
# Epoch 3/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.6207 - loss: 1.1856 - val_accuracy: 0.1348 - val_loss: 1.6485
# Epoch 4/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.7022 - loss: 0.8568 - val_accuracy: 0.4661 - val_loss: 1.2350
# Epoch 5/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.7574 - loss: 0.6640 - val_accuracy: 0.6857 - val_loss: 0.8704
# Epoch 6/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.8274 - loss: 0.4843 - val_accuracy: 0.7857 - val_loss: 0.6249
# Epoch 7/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - accuracy: 0.8792 - loss: 0.3612 - val_accuracy: 0.8652 - val_loss: 0.4072
# Epoch 8/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.9008 - loss: 0.3014 - val_accuracy: 0.8384 - val_loss: 0.4040
# Epoch 9/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9056 - loss: 0.2944 - val_accuracy: 0.8982 - val_loss: 0.2837
# Epoch 10/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9306 - loss: 0.2194 - val_accuracy: 0.9402 - val_loss: 0.2065
# Epoch 11/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9347 - loss: 0.2039 - val_accuracy: 0.9464 - val_loss: 0.1588
# Epoch 12/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9515 - loss: 0.1599 - val_accuracy: 0.9580 - val_loss: 0.1313
# Epoch 13/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9598 - loss: 0.1360 - val_accuracy: 0.9518 - val_loss: 0.1437
# Epoch 14/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9677 - loss: 0.1094 - val_accuracy: 0.9643 - val_loss: 0.1073
# Epoch 15/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9673 - loss: 0.1017 - val_accuracy: 0.9643 - val_loss: 0.1123
# Epoch 16/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step - accuracy: 0.9700 - loss: 0.1021 - val_accuracy: 0.9670 - val_loss: 0.1047
# Epoch 17/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step - accuracy: 0.9747 - loss: 0.0915 - val_accuracy: 0.9786 - val_loss: 0.0688
# Epoch 18/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9774 - loss: 0.0771 - val_accuracy: 0.9598 - val_loss: 0.1277
# Epoch 19/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.9733 - loss: 0.0895 - val_accuracy: 0.9786 - val_loss: 0.0640
# Epoch 20/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.9724 - loss: 0.0884 - val_accuracy: 0.9696 - val_loss: 0.0957
# Epoch 21/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9837 - loss: 0.0609 - val_accuracy: 0.9723 - val_loss: 0.0844
# Epoch 22/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9825 - loss: 0.0677 - val_accuracy: 0.9670 - val_loss: 0.0997
# Epoch 23/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9756 - loss: 0.0787 - val_accuracy: 0.9857 - val_loss: 0.0425
# Epoch 24/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.9813 - loss: 0.0634 - val_accuracy: 0.9643 - val_loss: 0.1071
# Epoch 25/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9779 - loss: 0.0686 - val_accuracy: 0.9732 - val_loss: 0.0937
# Epoch 26/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9830 - loss: 0.0692 - val_accuracy: 0.9875 - val_loss: 0.0363
# Epoch 27/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9849 - loss: 0.0513 - val_accuracy: 0.9857 - val_loss: 0.0508
# Epoch 28/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9865 - loss: 0.0414 - val_accuracy: 0.9821 - val_loss: 0.0405
# Epoch 29/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9884 - loss: 0.0423 - val_accuracy: 0.9848 - val_loss: 0.0402
# Epoch 30/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9915 - loss: 0.0317 - val_accuracy: 0.9804 - val_loss: 0.0658
# Epoch 31/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.9891 - loss: 0.0441 - val_accuracy: 0.9893 - val_loss: 0.0282
# Epoch 32/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.9869 - loss: 0.0423 - val_accuracy: 0.9714 - val_loss: 0.0857
# Epoch 33/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9836 - loss: 0.0555 - val_accuracy: 0.9857 - val_loss: 0.0428
# Epoch 34/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9796 - loss: 0.0695 - val_accuracy: 0.9321 - val_loss: 0.2582
# Epoch 35/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9810 - loss: 0.0704 - val_accuracy: 0.9857 - val_loss: 0.0416
# Epoch 36/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9879 - loss: 0.0388 - val_accuracy: 0.9884 - val_loss: 0.0350
# Epoch 37/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.9949 - loss: 0.0272 - val_accuracy: 0.9946 - val_loss: 0.0165
# Epoch 38/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9887 - loss: 0.0373 - val_accuracy: 0.9884 - val_loss: 0.0340
# Epoch 39/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.9928 - loss: 0.0248 - val_accuracy: 0.9937 - val_loss: 0.0194
# Epoch 40/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 241ms/step - accuracy: 0.9891 - loss: 0.0356 - val_accuracy: 0.9911 - val_loss: 0.0268
# Epoch 41/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.9930 - loss: 0.0297 - val_accuracy: 0.9955 - val_loss: 0.0137
# Epoch 42/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9881 - loss: 0.0338 - val_accuracy: 0.9973 - val_loss: 0.0107
# Epoch 43/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9927 - loss: 0.0296 - val_accuracy: 0.9937 - val_loss: 0.0162
# Epoch 44/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9952 - loss: 0.0193 - val_accuracy: 0.9946 - val_loss: 0.0166
# Epoch 45/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9931 - loss: 0.0232 - val_accuracy: 0.9902 - val_loss: 0.0262
# Epoch 46/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.9934 - loss: 0.0196 - val_accuracy: 0.9902 - val_loss: 0.0211
# Epoch 47/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9935 - loss: 0.0224 - val_accuracy: 0.9821 - val_loss: 0.0615
# Epoch 48/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9907 - loss: 0.0253 - val_accuracy: 0.9946 - val_loss: 0.0166
# Epoch 49/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 218ms/step - accuracy: 0.9947 - loss: 0.0188 - val_accuracy: 0.9973 - val_loss: 0.0098
# Epoch 50/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.9961 - loss: 0.0136 - val_accuracy: 0.9973 - val_loss: 0.0103
# Epoch 51/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9958 - loss: 0.0178 - val_accuracy: 0.9937 - val_loss: 0.0228
# Epoch 52/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - accuracy: 0.9942 - loss: 0.0218 - val_accuracy: 0.9902 - val_loss: 0.0312
# Epoch 53/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9953 - loss: 0.0156 - val_accuracy: 0.9991 - val_loss: 0.0048
# Epoch 54/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.9954 - loss: 0.0144 - val_accuracy: 0.9964 - val_loss: 0.0077
# Epoch 55/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9967 - loss: 0.0134 - val_accuracy: 0.9964 - val_loss: 0.0105
# Epoch 56/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - accuracy: 0.9943 - loss: 0.0215 - val_accuracy: 0.9964 - val_loss: 0.0091
# Epoch 57/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9927 - loss: 0.0239 - val_accuracy: 0.9750 - val_loss: 0.0853
# Epoch 58/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9860 - loss: 0.0580 - val_accuracy: 0.9964 - val_loss: 0.0137
# Epoch 59/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.9923 - loss: 0.0220 - val_accuracy: 0.9964 - val_loss: 0.0132
# Epoch 60/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9958 - loss: 0.0142 - val_accuracy: 0.9964 - val_loss: 0.0078
# Epoch 61/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9986 - loss: 0.0105 - val_accuracy: 0.9973 - val_loss: 0.0080
# Epoch 62/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9974 - loss: 0.0099 - val_accuracy: 0.9991 - val_loss: 0.0037
# Epoch 63/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9957 - loss: 0.0116 - val_accuracy: 0.9964 - val_loss: 0.0142
# Epoch 64/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.9981 - loss: 0.0092 - val_accuracy: 0.9991 - val_loss: 0.0028
# Epoch 65/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9982 - loss: 0.0084 - val_accuracy: 0.9982 - val_loss: 0.0049
# Epoch 66/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9968 - loss: 0.0093 - val_accuracy: 0.9991 - val_loss: 0.0035
# Epoch 67/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9984 - loss: 0.0074 - val_accuracy: 0.9964 - val_loss: 0.0104
# Epoch 68/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9966 - loss: 0.0121 - val_accuracy: 0.9955 - val_loss: 0.0099
# Epoch 69/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.9977 - loss: 0.0084 - val_accuracy: 0.9982 - val_loss: 0.0038
# Epoch 70/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.9979 - loss: 0.0070 - val_accuracy: 0.9991 - val_loss: 0.0032
# Epoch 71/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9987 - loss: 0.0050 - val_accuracy: 0.9937 - val_loss: 0.0160
# Epoch 72/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 214ms/step - accuracy: 0.9968 - loss: 0.0101 - val_accuracy: 0.9982 - val_loss: 0.0126
# Epoch 73/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - accuracy: 0.9936 - loss: 0.0285 - val_accuracy: 0.9973 - val_loss: 0.0093
# Epoch 74/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9951 - loss: 0.0201 - val_accuracy: 0.9937 - val_loss: 0.0144
# Epoch 75/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.9962 - loss: 0.0149 - val_accuracy: 0.9946 - val_loss: 0.0106
# Epoch 76/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9963 - loss: 0.0113 - val_accuracy: 0.9937 - val_loss: 0.0159
# Epoch 77/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9975 - loss: 0.0112 - val_accuracy: 0.9973 - val_loss: 0.0050
# Epoch 78/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 0.9973 - val_loss: 0.0093
# Epoch 79/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 202ms/step - accuracy: 0.9985 - loss: 0.0065 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 80/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9990 - loss: 0.0045 - val_accuracy: 0.9982 - val_loss: 0.0041
# Epoch 81/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.9980 - loss: 0.0082 - val_accuracy: 0.9991 - val_loss: 0.0015
# Epoch 82/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9984 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 83/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 211ms/step - accuracy: 0.9999 - loss: 0.0027 - val_accuracy: 0.9991 - val_loss: 0.0014
# Epoch 84/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9991 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 6.3794e-04
# Epoch 85/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.9992 - loss: 0.0042 - val_accuracy: 0.9991 - val_loss: 0.0023
# Epoch 86/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9991 - val_loss: 0.0012
# Epoch 87/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.9992 - loss: 0.0031 - val_accuracy: 0.9991 - val_loss: 0.0016
# Epoch 88/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.9988 - loss: 0.0062 - val_accuracy: 0.9991 - val_loss: 0.0028
# Epoch 89/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9981 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 90/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9986 - loss: 0.0064 - val_accuracy: 0.9946 - val_loss: 0.0159
# Epoch 91/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.9977 - loss: 0.0087 - val_accuracy: 0.9964 - val_loss: 0.0122
# Epoch 92/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.9980 - loss: 0.0070 - val_accuracy: 0.9973 - val_loss: 0.0052
# Epoch 93/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 207ms/step - accuracy: 0.9981 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 7.5180e-04
# Epoch 94/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 198ms/step - accuracy: 0.9989 - loss: 0.0055 - val_accuracy: 0.9973 - val_loss: 0.0126
# Epoch 95/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9981 - loss: 0.0045 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 96/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.9987 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 97/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 201ms/step - accuracy: 0.9983 - loss: 0.0043 - val_accuracy: 0.9937 - val_loss: 0.0235
# Epoch 98/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 210ms/step - accuracy: 0.9962 - loss: 0.0171 - val_accuracy: 0.9955 - val_loss: 0.0105
# Epoch 99/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9929 - val_loss: 0.0235
# Epoch 100/100
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.9988 - loss: 0.0065 - val_accuracy: 0.9982 - val_loss: 0.0072

# %%
epochs=list(range(100))
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']

plt.plot(epochs,acc,label='train accuracy')
plt.plot(epochs,val_acc,label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('epochs')
plt.legend()
plt.show()

# %%
loss=history.history['loss']
val_loss=history.history['val_loss']

plt.plot(epochs,loss,label='train loss')
plt.plot(epochs,val_loss,label='val loss')
plt.xlabel('epochs')
plt.ylabel('epochs')
plt.legend()
plt.show()
